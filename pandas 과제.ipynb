# %%
import pandas as pd

# %%
df1=pd.DataFrame(
    {"이름" : ['손흥민','메시', '호날두'],
     "나이" : [28, 33, 35],
     "소속" : ['토트넘', '바르셀로나','유벤투스']}
)

# %%
df1
# Out:
#     이름  나이     소속
# 0  손흥민  28    토트넘
# 1   메시  33  바르셀로나
# 2  호날두  35   유벤투스

# %%
df1 = pd.DataFrame(
    {"이름" : ['손흥민','메시', '호날두'],
     "나이" : [28, 33, 35],
     "소속" : ['토트넘', '바르셀로나','유벤투스']},
    index = [1,2,3]
)

# %%
df1
# Out:
#     이름  나이     소속
# 1  손흥민  28    토트넘
# 2   메시  33  바르셀로나
# 3  호날두  35   유벤투스

# %%
player_list =[
        ['손흥민', 28, '토트넘'],
        ['메시', 33, '바르셀로나'],
        ['호날두', 35, '유벤투스']
    ]
df2 = pd.DataFrame(player_list, columns=['이름', '나이', '소속'])

# %%
df2
# Out:
#     이름  나이     소속
# 0  손흥민  28    토트넘
# 1   메시  33  바르셀로나
# 2  호날두  35   유벤투스

# %%
pd.read_csv('transfermarket50.csv')
# Out:
#     number                     name            position  age        nation  \
# 0        1            Kylian Mbappé      Centre-Forward   22        France
# 1        2                   Neymar         Left Winger   28        Brazil
# 2        3               Sadio Mané         Left Winger   28       Senegal
# 3        4            Mohamed Salah        Right Winger   28         Egypt
# 4        5               Harry Kane      Centre-Forward   27       England
# 5        6          Kevin De Bruyne  Attacking Midfield   29       Belgium
# 6        7   Trent Alexander-Arnold          Right-Back   22       England
# 7        8          Raheem Sterling         Left Winger   26       England
# 8        9               João Félix      Second Striker   21      Portugal
# 9       10           Erling Haaland      Centre-Forward   20        Norway
# 10      11             Jadon Sancho        Right Winger   20       England
# 11      12          Bruno Fernandes  Attacking Midfield   26      Portugal
# 12      13             Serge Gnabry        Right Winger   25       Germany
# 13      14                Jan Oblak          Goalkeeper   28      Slovenia
# 14      15            Romelu Lukaku      Centre-Forward   27       Belgium
# 15      16            Heung-min Son         Left Winger   28  Korea, South
# 16      17           Joshua Kimmich  Defensive Midfield   25       Germany
# 17      18              Kai Havertz  Attacking Midfield   21       Germany
# 18      19                Ansu Fati         Left Winger   18         Spain
# 19      20          Alphonso Davies           Left-Back   20        Canada
# 20      21          Marcus Rashford         Left Winger   23       England
# 21      22          Virgil van Dijk         Centre-Back   29   Netherlands
# 22      23                  Alisson          Goalkeeper   28        Brazil
# 23      24             Lionel Messi        Right Winger   33     Argentina
# 24      25         Matthijs de Ligt         Centre-Back   21   Netherlands
# 25      26         Andrew Robertson           Left-Back   26      Scotland
# 26      27         Thibaut Courtois          Goalkeeper   28       Belgium
# 27      28    Marc-André ter Stegen          Goalkeeper   28       Germany
# 28      29          Roberto Firmino      Centre-Forward   29        Brazil
# 29      30         Lautaro Martínez      Centre-Forward   23     Argentina
# 30      31        Federico Valverde    Central Midfield   22       Uruguay
# 31      32          Mikel Oyarzabal         Left Winger   23         Spain
# 32      33  Sergej Milinkovic-Savic    Central Midfield   25        Serbia
# 33      34           Bernardo Silva        Right Winger   26      Portugal
# 34      35             Paulo Dybala      Second Striker   27     Argentina
# 35      36               Leroy Sané         Left Winger   25       Germany
# 36      37               Marquinhos         Centre-Back   26        Brazil
# 37      38              Timo Werner      Centre-Forward   24       Germany
# 38      39           Raphaël Varane         Centre-Back   27        France
# 39      40                 Casemiro  Defensive Midfield   28        Brazil
# 40      41          Frenkie de Jong    Central Midfield   23   Netherlands
# 41      42       José María Giménez         Centre-Back   26       Uruguay
# 42      43               Paul Pogba    Central Midfield   27        France
# 43      44              David Alaba         Centre-Back   28       Austria
# 44      45                    Rodri  Defensive Midfield   24         Spain
# 45      46        Eduardo Camavinga    Central Midfield   18        France
# 46      47               Phil Foden    Central Midfield   20       England
# 47      48              Richarlison      Centre-Forward   23        Brazil
# 48      49            Gabriel Jesus      Centre-Forward   23        Brazil
# 49      50          Dayot Upamecano         Centre-Back   22        France
#
#                    team     value
# 0   Paris Saint-Germain  £162.00m
# 1   Paris Saint-Germain  £115.20m
# 2          Liverpool FC  £108.00m
# 3          Liverpool FC  £108.00m
# 4     Tottenham Hotspur  £108.00m
# 5       Manchester City  £108.00m
# 6          Liverpool FC   £99.00m
# 7       Manchester City   £99.00m
# 8       Atlético Madrid   £90.00m
# 9     Borussia Dortmund   £90.00m
# 10    Borussia Dortmund   £90.00m
# 11    Manchester United   £81.00m
# 12        Bayern Munich   £81.00m
# 13      Atlético Madrid   £81.00m
# 14          Inter Milan   £81.00m
# 15    Tottenham Hotspur   £81.00m
# 16        Bayern Munich   £76.50m
# 17           Chelsea FC   £72.90m
# 18         FC Barcelona   £72.00m
# 19        Bayern Munich   £72.00m
# 20    Manchester United   £72.00m
# 21         Liverpool FC   £72.00m
# 22         Liverpool FC   £72.00m
# 23         FC Barcelona   £72.00m
# 24          Juventus FC   £67.50m
# 25         Liverpool FC   £67.50m
# 26          Real Madrid   £67.50m
# 27         FC Barcelona   £67.50m
# 28         Liverpool FC   £64.80m
# 29          Inter Milan   £63.00m
# 30          Real Madrid   £63.00m
# 31        Real Sociedad   £63.00m
# 32             SS Lazio   £63.00m
# 33      Manchester City   £63.00m
# 34          Juventus FC   £63.00m
# 35        Bayern Munich   £63.00m
# 36  Paris Saint-Germain   £63.00m
# 37           Chelsea FC   £63.00m
# 38          Real Madrid   £63.00m
# 39          Real Madrid   £63.00m
# 40         FC Barcelona   £58.50m
# 41      Atlético Madrid   £58.50m
# 42    Manchester United   £58.50m
# 43        Bayern Munich   £58.50m
# 44      Manchester City   £57.60m
# 45     Stade Rennais FC   £54.00m
# 46      Manchester City   £54.00m
# 47           Everton FC   £54.00m
# 48      Manchester City   £54.00m
# 49           RB Leipzig   £54.00m

# %%
df.shape
# Out:
# (50, 7)

# %%
df[['number','name', 'nation']].head()
# Out:
#    number           name   nation
# 0       1  Kylian Mbappé   France
# 1       2         Neymar   Brazil
# 2       3     Sadio Mané  Senegal
# 3       4  Mohamed Salah    Egypt
# 4       5     Harry Kane  England

# %%
df.iloc[0:2]
# Out:
#    number           name        position  age  nation                 team  \
# 0       1  Kylian Mbappé  Centre-Forward   22  France  Paris Saint-Germain
# 1       2         Neymar     Left Winger   28  Brazil  Paris Saint-Germain
#
#       value
# 0  £162.00m
# 1  £115.20m

# %%
df[0:2]
# Out:
#    number           name        position  age  nation                 team  \
# 0       1  Kylian Mbappé  Centre-Forward   22  France  Paris Saint-Germain
# 1       2         Neymar     Left Winger   28  Brazil  Paris Saint-Germain
#
#       value
# 0  £162.00m
# 1  £115.20m

# %%
df.loc[0:2]
# Out:
#    number           name        position  age   nation                 team  \
# 0       1  Kylian Mbappé  Centre-Forward   22   France  Paris Saint-Germain
# 1       2         Neymar     Left Winger   28   Brazil  Paris Saint-Germain
# 2       3     Sadio Mané     Left Winger   28  Senegal         Liverpool FC
#
#       value
# 0  £162.00m
# 1  £115.20m
# 2  £108.00m

# %%
df.loc[0,'name']
# Out:
# 'Kylian Mbappé'

# %%
df.loc[0:5,['name', 'team', 'value']]
# Out:
#               name                 team     value
# 0    Kylian Mbappé  Paris Saint-Germain  £162.00m
# 1           Neymar  Paris Saint-Germain  £115.20m
# 2       Sadio Mané         Liverpool FC  £108.00m
# 3    Mohamed Salah         Liverpool FC  £108.00m
# 4       Harry Kane    Tottenham Hotspur  £108.00m
# 5  Kevin De Bruyne      Manchester City  £108.00m

# %%
df[df['age']<=20]
# Out:
#     number               name          position  age   nation  \
# 9       10     Erling Haaland    Centre-Forward   20   Norway
# 10      11       Jadon Sancho      Right Winger   20  England
# 18      19          Ansu Fati       Left Winger   18    Spain
# 19      20    Alphonso Davies         Left-Back   20   Canada
# 45      46  Eduardo Camavinga  Central Midfield   18   France
# 46      47         Phil Foden  Central Midfield   20  England
#
#                  team  시장가치(억)
# 9   Borussia Dortmund   1170.0
# 10  Borussia Dortmund   1170.0
# 18       FC Barcelona    936.0
# 19      Bayern Munich    936.0
# 45   Stade Rennais FC    702.0
# 46    Manchester City    702.0

# %%
df.loc[df['age']>=30, ['name', 'value']]
# Out:
#             name    value
# 23  Lionel Messi  £72.00m

# %%
df.head()
df.sort_index().head()
# Out:
#    number           name        position  age   nation                 team  \
# 0       1  Kylian Mbappé  Centre-Forward   22   France  Paris Saint-Germain
# 1       2         Neymar     Left Winger   28   Brazil  Paris Saint-Germain
# 2       3     Sadio Mané     Left Winger   28  Senegal         Liverpool FC
# 3       4  Mohamed Salah    Right Winger   28    Egypt         Liverpool FC
# 4       5     Harry Kane  Centre-Forward   27  England    Tottenham Hotspur
#
#       value
# 0  £162.00m
# 1  £115.20m
# 2  £108.00m
# 3  £108.00m
# 4  £108.00m

# %%
df.sort_index(ascending=False)[:5]
# Out:
#     number               name          position  age   nation  \
# 49      50    Dayot Upamecano       Centre-Back   22   France
# 48      49      Gabriel Jesus    Centre-Forward   23   Brazil
# 47      48        Richarlison    Centre-Forward   23   Brazil
# 46      47         Phil Foden  Central Midfield   20  England
# 45      46  Eduardo Camavinga  Central Midfield   18   France
#
#                 team    value
# 49        RB Leipzig  £54.00m
# 48   Manchester City  £54.00m
# 47        Everton FC  £54.00m
# 46   Manchester City  £54.00m
# 45  Stade Rennais FC  £54.00m

# %%
df.sort_values("age", ascending=False).head()
# Out:
#     number             name            position  age       nation  \
# 23      24     Lionel Messi        Right Winger   33    Argentina
# 5        6  Kevin De Bruyne  Attacking Midfield   29      Belgium
# 28      29  Roberto Firmino      Centre-Forward   29       Brazil
# 21      22  Virgil van Dijk         Centre-Back   29  Netherlands
# 43      44      David Alaba         Centre-Back   28      Austria
#
#                team     value
# 23     FC Barcelona   £72.00m
# 5   Manchester City  £108.00m
# 28     Liverpool FC   £64.80m
# 21     Liverpool FC   £72.00m
# 43    Bayern Munich   £58.50m

# %%
df.set_index('number').head()
# Out:
#                  name        position  age   nation                 team  \
# number
# 1       Kylian Mbappé  Centre-Forward   22   France  Paris Saint-Germain
# 2              Neymar     Left Winger   28   Brazil  Paris Saint-Germain
# 3          Sadio Mané     Left Winger   28  Senegal         Liverpool FC
# 4       Mohamed Salah    Right Winger   28    Egypt         Liverpool FC
# 5          Harry Kane  Centre-Forward   27  England    Tottenham Hotspur
#
#         시장가치(억)
# number
# 1        2106.0
# 2        1497.6
# 3        1404.0
# 4        1404.0
# 5        1404.0

# %%
df['value']=df['value'].replace('£','')
df.head()
# Out:
#    number           name        position  age   nation                 team  \
# 0       1  Kylian Mbappé  Centre-Forward   22   France  Paris Saint-Germain
# 1       2         Neymar     Left Winger   28   Brazil  Paris Saint-Germain
# 2       3     Sadio Mané     Left Winger   28  Senegal         Liverpool FC
# 3       4  Mohamed Salah    Right Winger   28    Egypt         Liverpool FC
# 4       5     Harry Kane  Centre-Forward   27  England    Tottenham Hotspur
#
#    value
# 0  162.0
# 1  115.2
# 2  108.0
# 3  108.0
# 4  108.0

# %%
df.describe()
# Out:
#          number       age       value
# count  50.00000  50.00000   50.000000
# mean   25.50000  24.88000   75.060000
# std    14.57738   3.30516   20.760205
# min     1.00000  18.00000   54.000000
# 25%    13.25000  22.25000   63.000000
# 50%    25.50000  25.50000   67.500000
# 75%    37.75000  28.00000   81.000000
# max    50.00000  33.00000  162.000000

# %%
df['age'].mean()
# Out:
# 24.88

# %%
df['시장가치(억)'].sum()
# Out:
# 48789.0

# %%
df['시장가치(억)']=df['value']*13
df.head()
# Out:
#    number           name        position  age   nation                 team  \
# 0       1  Kylian Mbappé  Centre-Forward   22   France  Paris Saint-Germain
# 1       2         Neymar     Left Winger   28   Brazil  Paris Saint-Germain
# 2       3     Sadio Mané     Left Winger   28  Senegal         Liverpool FC
# 3       4  Mohamed Salah    Right Winger   28    Egypt         Liverpool FC
# 4       5     Harry Kane  Centre-Forward   27  England    Tottenham Hotspur
#
#    value  시장가치(억)
# 0  162.0   2106.0
# 1  115.2   1497.6
# 2  108.0   1404.0
# 3  108.0   1404.0
# 4  108.0   1404.0

# %%
df.drop(columns=['value'], inplace=True)

# %%
g = df.groupby('nation')
g.size()
# Out:
# nation
# Argentina       3
# Austria         1
# Belgium         3
# Brazil          7
# Canada          1
# Egypt           1
# England         6
# France          5
# Germany         6
# Korea, South    1
# Netherlands     3
# Norway          1
# Portugal        3
# Scotland        1
# Senegal         1
# Serbia          1
# Slovenia        1
# Spain           3
# Uruguay         2
# dtype: int64

# %%
g.count()
# Out:
#               number  name  position  age  team  시장가치(억)
# nation
# Argentina          3     3         3    3     3        3
# Austria            1     1         1    1     1        1
# Belgium            3     3         3    3     3        3
# Brazil             7     7         7    7     7        7
# Canada             1     1         1    1     1        1
# Egypt              1     1         1    1     1        1
# England            6     6         6    6     6        6
# France             5     5         5    5     5        5
# Germany            6     6         6    6     6        6
# Korea, South       1     1         1    1     1        1
# Netherlands        3     3         3    3     3        3
# Norway             1     1         1    1     1        1
# Portugal           3     3         3    3     3        3
# Scotland           1     1         1    1     1        1
# Senegal            1     1         1    1     1        1
# Serbia             1     1         1    1     1        1
# Slovenia           1     1         1    1     1        1
# Spain              3     3         3    3     3        3
# Uruguay            2     2         2    2     2        2

# %%
g['시장가치(억)'].sum()
# Out:
# nation
# Argentina       2574.0
# Austria          760.5
# Belgium         3334.5
# Brazil          6318.0
# Canada           936.0
# Egypt           1404.0
# England         6786.0
# France          5089.5
# Germany         5510.7
# Korea, South    1053.0
# Netherlands     2574.0
# Norway          1170.0
# Portugal        3042.0
# Scotland         877.5
# Senegal         1404.0
# Serbia           819.0
# Slovenia        1053.0
# Spain           2503.8
# Uruguay         1579.5
# Name: 시장가치(억), dtype: float64

# %%
df.rename(columns = {'team':'club'}, inplace=True)

# %%
c = df.groupby("club")
c.sum()
# Out:
#                      number  age  시장가치(억)
# club
# Atlético Madrid          65   75   2983.5
# Bayern Munich           130  123   4563.0
# Borussia Dortmund        21   40   2340.0
# Chelsea FC               56   45   1766.7
# Everton FC               48   23    702.0
# FC Barcelona            112  102   3510.0
# Inter Milan              45   50   1872.0
# Juventus FC              60   48   1696.5
# Liverpool FC            114  190   7686.9
# Manchester City         189  148   5662.8
# Manchester United        76   76   2749.5
# Paris Saint-Germain      40   76   4422.6
# RB Leipzig               50   22    702.0
# Real Madrid             137  105   3334.5
# Real Sociedad            32   23    819.0
# SS Lazio                 33   25    819.0
# Stade Rennais FC         46   18    702.0
# Tottenham Hotspur        21   55   2457.0

# %%
c.sum().sort_values('시장가치(억)', ascending=False)
# Out:
#                      number  age  시장가치(억)
# club
# Liverpool FC            114  190   7686.9
# Manchester City         189  148   5662.8
# Bayern Munich           130  123   4563.0
# Paris Saint-Germain      40   76   4422.6
# FC Barcelona            112  102   3510.0
# Real Madrid             137  105   3334.5
# Atlético Madrid          65   75   2983.5
# Manchester United        76   76   2749.5
# Tottenham Hotspur        21   55   2457.0
# Borussia Dortmund        21   40   2340.0
# Inter Milan              45   50   1872.0
# Chelsea FC               56   45   1766.7
# Juventus FC              60   48   1696.5
# Real Sociedad            32   23    819.0
# SS Lazio                 33   25    819.0
# Everton FC               48   23    702.0
# RB Leipzig               50   22    702.0
# Stade Rennais FC         46   18    702.0

# %%
c['시장가치(억)'].sum().sort_values(ascending=False)
# Out:
# club
# Liverpool FC           7686.9
# Manchester City        5662.8
# Bayern Munich          4563.0
# Paris Saint-Germain    4422.6
# FC Barcelona           3510.0
# Real Madrid            3334.5
# Atlético Madrid        2983.5
# Manchester United      2749.5
# Tottenham Hotspur      2457.0
# Borussia Dortmund      2340.0
# Inter Milan            1872.0
# Chelsea FC             1766.7
# Juventus FC            1696.5
# Real Sociedad           819.0
# SS Lazio                819.0
# RB Leipzig              702.0
# Stade Rennais FC        702.0
# Everton FC              702.0
# Name: 시장가치(억), dtype: float64
